# %%
import control as ctl

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
G1 = ctl.tf([1],[1,0,0])

# %%
G1
# Out:
#  1
# ---
# s^2

# %%
ctl.margin(G1)
# Out:
# (inf, 0.0, nan, 0.9999999999999999)

# %%
G2 = 0.05

# %%
ctl.margin(G1*G2)
# Out:
# (inf, 0.0, nan, 0.22360679774997896)

# %%
ctl.bode(G1*G2)

plt.show()

# %%
ctl.tf2ss([1,2,5],[1,1,1])
# Out:
# A = [[-1. -1.]
#  [ 1.  0.]]
#
# B = [[1.]
#  [0.]]
#
# C = [[1. 4.]]
#
# D = [[1.]]

# %%
C = ctl.tf([1],[1, -5 , 6])

ctl.rlocus(G1*C)
plt.show()
